# %%
from datetime import date

# %%
from jobsplatform.models import Job
from organizer.models import Tag
from organizer.models import Company, Partner
from resume.models import Skill, Experience, Task, Institution, Education, Contact, Link, Resume

from datetime import datetime

sk1 = Skill.objects.create(
    name="Dog Walker",
    slug="dog-walker",
    description="Walks dogs around the park",
)

cp1 = Company.objects.create(
    name='Cool Walker',
    slug='cool-walker',
    location='NY/New York'
)

exp1 = Experience.objects.create(
    company=cp1,
    slug='exp1',
    started_at=datetime.today(),
    current=False
)

tsk1 = Task.objects.create(
    experience=exp1,
    slug='task1',
    description='This is a description',
)

ins1 = Institution.objects.create(
    name="Cool School",
    slug='cool-school',
)

ed1 = Education.objects.create(
    slug='ed1',
    degree_type='HS',
    institution=ins1,
    started_at=datetime.today(),
    ended_at=datetime.today(),
    current=False
)

exp1 = Experience.objects.create(
    company=cp1,
    slug='exp1',
    started_at=datetime.today(),
    current=False
)

exp2 = Experience.objects.create(
    company=pt1,
    slug='exp1',
    started_at=datetime.today(),
    current=False)

tsk1 = Task.objects.create(
    experience=exp1,
    slug='task1',
    description='This is a description',
)

ins1 = Institution.objects.create(
    name="Cool School",
    slug='cool-school',
)

ed1 = Education.objects.create(
    slug='ed1',
    degree_type='HS',
    institution=ins1,
    started_at=datetime.today(),
    ended_at=datetime.today(),
    current=False
)

ct1 = Contact.objects.create(
    contact_type="P",
    slug='phone1',
    contact='97889172389',
)

ct2 = Contact.objects.create(
    contact_type="E",
    slug='email-1',
    contact='email@example.com',
)

lk1= Link.objects.create(
    link_type='W',
    slug='link1',
    link='www.mysite.com',
)

lk2 = Link.objects.create(
    link_type='R',
    slug='rep1',
    link='www.github.com/user',
)

pt1 = Partner.objects.create(
    name='Walkery Walk',
    slug='walkery-walk',
    location='NY/New York',
    contact='980912830',
    description='Makes appointments between dog walkers and customers',
    website='walkery.com',
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-60c4e5db5b08> in <module>
# ----> 1 from ..jobsplatform.models import Job
#       2 from organizer.models import Tag
#       3 from organizer.models import Company, Partner
#       4 from resume.models import Skill, Experience, Task, Institution, Education, Contact, Link, Resume
#
# ImportError: attempted relative import with no known parent package

# %%
Job
